# %%
total_chocolates = 327
num_students = 78

chocolates_per_student = total_chocolates // num_students
remaining_chocolates = total_chocolates % num_students

print(f"Number of chocolates per student: {chocolates_per_student}")
print(f"Remaining chocolates with the teacher: {remaining_chocolates}")
# Out:
# Number of chocolates per student: 4
# Remaining chocolates with the teacher: 15

# %%
customer_name = input("Enter your name: ")
customer_mobile_number = input("Enter your mobile number: ")
customer_age = input("Enter your age: ")
customer_email_id = input("Enter your email ID: ")

print(f"Hi {customer_name}!! Thanks for visiting our restaurant and registering for our lucky draw competition on our 25th Anniversary.")
print(f"Once the lucky draw results are announced, you will receive a message on your mobile number: {customer_mobile_number}")
print(f"A detailed description of your gift will be sent to your email ID: {customer_email_id}")
print(f"Thank you for being a valued customer, {customer_name}!!\nDominos 25th Anniversary")
# Out:
# Enter your name: nikhil
# Enter your mobile number: 8368339387
# Enter your age: 22
# Enter your email ID: nikhilkalkhanda@gmail.com
# Hi nikhil!! Thanks for visiting our restaurant and registering for our lucky draw competition on our 25th Anniversary.
# Once the lucky draw results are announced, you will receive a message on your mobile number: 8368339387
# A detailed description of your gift will be sent to your email ID: nikhilkalkhanda@gmail.com
# Thank you for being a valued customer, nikhil!!
# Dominos 25th Anniversary

# %%
total_students = 60
students_per_team = 4
total_teams = total_students // students_per_team
print(f"Total number of teams that can be created among {total_students} students with {students_per_team} students per team: {total_teams}")
# Out:
# Total number of teams that can be created among 60 students with 4 students per team: 15

# %%
temperature_fahrenheit = float(input("Enter temperature in Fahrenheit: "))
temperature_celsius = (temperature_fahrenheit - 32) * 5/9
print(f"Temperature in Celsius: {temperature_celsius}")
# Out:
# Enter temperature in Fahrenheit: 104
# Temperature in Celsius: 40.0
