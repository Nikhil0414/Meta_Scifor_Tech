# %%
print("Arvind")
print("Nikhil")
print("21")
# Out:
# Arvind
# Nikhil
# 21

# %%
print("Karthik \nVedant \nVignesh \nKrishna \nYaseen\n")
# Out:
# Karthik
# Vedant
# Vignesh
# Krishna
# Yaseen

# %%
print("Rectangle:")
print(" ______ ")
print("|      |")
print(" ------ ")

print("Square:")
print(" __")
print("|  |")
print(" --")

print("\nTriangle:")
print("/\\")
# Out:
# Rectangle:
#  ______
# |      |
#  ------
# Square:
#  __
# |  |
#  --
#
# Triangle:
# /\
# -

# %%
name = input("What is your name? ")
age = input("How old are you? ")
address = input("Where do you live? ")

print(f"\nEssay about {name}:")
print(f"My name is {name}. I am {age} years old. I live in {address}. This is a brief introduction about myself.")

print("\nHi, I am a chatbot. What is your name?")
user_name = input(">> ")
print(f"Oh, {user_name}, in which college year are you right now?")
grade = input(">> ")
print(f"{user_name}, you are in {grade}th year. Can I ask you one question? yes or no?")
response = input(">> ")
if response.lower() == "yes":
    print("Tell me 1024+98=?")
    answer = input(">> ")
    if answer == "1122":
        print("Good! Your answer is correct. Bye")
    else:
        print("Oops! Your answer is incorrect. Better luck next time. Bye")
else:
    print("Okay, no problem. Bye")
# Out:
# What is your name? nikhil
# How old are you? 21
# Where do you live? delhi
#
# Essay about nikhil:
# My name is nikhil. I am 21 years old. I live in delhi. This is a brief introduction about myself.
#
# Hi, I am a chatbot. What is your name?
# >> nikhil
# Oh, nikhil, in which college year are you right now?
# >> 4
# nikhil, you are in 4th year. Can I ask you one question? yes or no?
# >> yes
# Tell me 1024+98=?
# >> 1122
# Good! Your answer is correct. Bye

# %%
notebooks = int(input("Enter the number of notebooks to buy: "))
cost = 2
total_amount = notebooks * cost
print("Total amount to be paid: $",total_amount)
# Out:
# Enter the number of notebooks to buy: 5
# Total amount to be paid: $ 10

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2 if num2 != 0 else "Cannot divide by zero"

print(f"Addition: {addition}")
print(f"Subtraction: {subtraction}")
print(f"Multiplication: {multiplication}")
print(f"Division: {division}")
# Out:
# Enter the first number: 12
# Enter the second number: 24
# Addition: 36.0
# Subtraction: -12.0
# Multiplication: 288.0
# Division: 0.5

# %%
birth=int(input("Birth Year:"))
current=2024
age= current - birth
print("Age:",age)
# Out:
# Birth Year:2002
# Age: 22
