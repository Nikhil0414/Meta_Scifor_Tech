# %%
def intersection(set1, set2):
    result = []
    for element in set1:
        if element in set2:
            result.append(element)
    return result

def complement(universal_set, set_to_complement):
    result = []
    for element in universal_set:
        if element not in set_to_complement:
            result.append(element)
    return result

set1 = {1, 2, 3, 4, 5}
set2 = {3, 4, 5, 6, 7}

intersection_result = intersection(set1, set2)
complement_result = complement(set(range(1, 11)), set1)

print("Intersection:", intersection_result)
print("Complement:", complement_result)
# Out:
# Intersection: [3, 4, 5]
# Complement: [6, 7, 8, 9, 10]

# %%
# Define student details
students = {
    'student1': {
        'name': 'John',
        'age': 18,
        'subjects': {'math': 90, 'english': 85, 'science': 92}
    },
    'student2': {
        'name': 'Alice',
        'age': 17,
        'subjects': {'math': 88, 'english': 92, 'science': 89}
    },
    'student3': {
        'name': 'Bob',
        'age': 18,
        'subjects': {'math': 95, 'english': 78, 'science': 86}
    },
    'student4': {
        'name': 'Eva',
        'age': 17,
        'subjects': {'math': 82, 'english': 91, 'science': 94}
    },
    'student5': {
        'name': 'Charlie',
        'age': 18,
        'subjects': {'math': 87, 'english': 88, 'science': 90}
    },
}

student_id = 'student3'
print(f"Details of {student_id}: {students[student_id]}")
# Out:
# Details of student3: {'name': 'Bob', 'age': 18, 'subjects': {'math': 95, 'english': 78, 'science': 86}}

# %%
def union(set1, set2):
    result = list(set1)

    for element in set2:
        if element not in set1:
            result.append(element)

    return result

A = {19, 34, 56, 7}
B = {1, 2, 5, 19, 34, 7}

union_result = union(A, B)
print("Union:", union_result)
# Out:
# Union: [56, 34, 19, 7, 1, 2, 5]

# %%
def sort_questions(question_list):
    n = len(question_list)

    for i in range(n):
        for j in range(0, n-i-1):
            if question_list[j] > question_list[j+1]:
                question_list[j], question_list[j+1] = question_list[j+1], question_list[j]

total_questions = int(input("Enter total number of questions: "))

questions = []
print("Enter question numbers here:")
for _ in range(total_questions):
    question = int(input())
    questions.append(question)

print("Selected questions are:", questions)

2sort_questions(questions)

print("Selected questions in order:", questions)
# Out:
# Enter total number of questions: 5
# Enter question numbers here:
# 3
# 4
# 1
# 5
# 2
# Selected questions are: [3, 4, 1, 5, 2]
# Selected questions in order: [1, 2, 3, 4, 5]

# %%
def sort_questions(question_list):
    n = len(question_list)
    for i in range(n):
        for j in range(0, n-i-1):
            if question_list[j] > question_list[j+1]:
                question_list[j], question_list[j+1] = question_list[j+1], question_list[j]

def find_page_number(sorted_questions, target_question):
    for i, question in enumerate(sorted_questions):
        if question == target_question:
            return i + 1
    return -1

total_questions = int(input("Enter total number of questions: "))
questions = []
print("Enter question numbers here:")
for _ in range(total_questions):
    question = int(input())
    questions.append(question)

print("Selected questions are:", questions)

sort_questions(questions)
print("Selected questions in order:", questions)

target_question = int(input("Enter the question number: "))
page_number = find_page_number(questions, target_question)
if page_number != -1:
    print(f"Solve it on page number {page_number}.")
else:
    print("You don’t have to solve this question.")
# Out:
# Enter total number of questions: 6
# Enter question numbers here:
# 3
# 4
# 1
# 6
# 2
# 5
# Selected questions are: [3, 4, 1, 6, 2, 5]
# Selected questions in order: [1, 2, 3, 4, 5, 6]
# Enter the question number: 4
# Solve it on page number 4.
